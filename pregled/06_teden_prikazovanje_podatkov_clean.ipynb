# %% [markdown]
# # Uvod

# %%
# %matplotlib notebook
#to nam omogoči interaktivne figure v jupyterju

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## pyplot
#
#
# ## The Matplotlib Object Hierarchy

# %% [markdown]
# - FIGURE
# - AXES (SUBPLOT) -> več grafov (ni mišljeno kot več osi), podobjekt FIGURE
# - lastnosti grafa

# %% [markdown]
# ### Simple plot

# %%
import numpy as np

#za x os
x = np.linspace(-np.pi, np.pi, 256)

#za y os
C = np.cos(x)
S = np.sin(x)

# %%
plt.figure()
#vse kar pišemo pod to plt.figure(), se navezuje na ta figure
plt.plot(x, C)
plt.plot(x, S)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %% [markdown]
# ### Matplotlib - osnovne lastnosti

# %%
import csv
import numpy as np

year = list()
physical_sciences = list()
computer_science = list()
health = list()
education = list()

with open('data/DATA_percent-bachelors-degrees-women-usa.csv', 'r') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    line_count = 0
    for row in csv_reader:
        year.append(int(row['Year']))
        physical_sciences.append(float(row['Physical Sciences']))
        computer_science.append(float(row['Computer Science']))
        health.append(float(row['Health Professions']))
        education.append(float(row['Education']))

year = np.array(year)    
physical_sciences = np.array(physical_sciences)    
computer_science = np.array(computer_science)    
health = np.array(health)    
education = np.array(education)

# %%
# !head -n 3 data/DATA_percent-bachelors-degrees-women-usa.csv
# Out:
# Year,Agriculture,Architecture,Art and Performance,Biology,Business,Communications and Journalism,Computer Science,Education,Engineering,English,Foreign Languages,Health Professions,Math and Statistics,Physical Sciences,Psychology,Public Administration,Social Sciences and History
# 1970,4.22979798,11.92100539,59.7,29.08836297,9.064438975,35.3,13.6,74.53532758,0.8,65.57092343,73.8,77.1,38,13.8,44.4,68.4,36.8
# 1971,5.452796685,12.00310559,59.9,29.39440285,9.503186594,35.5,13.6,74.14920369,1,64.55648516,73.9,75.5,39,14.9,46.2,65.5,36.2

# %%
year
# Out:
# array([1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980,
#        1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991,
#        1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002,
#        2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011])

# %% [markdown]
# **Figures**

# %%
plt.figure(figsize=(8,6), dpi=80)
plt.plot(year, physical_sciences, c='blue')
plt.plot(year, computer_science, c='green')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Axes**

# %%
#v en figure želimo dati dva grafa
plt.figure(figsize=(8,6), dpi=80)

#prvi axes
#naredimo okvir v katerem bo naš graf
#vse kar pišemo pod tem spada pod ta axes
plt.axes([0.05, 0.05, 0.425, 0.9])
plt.plot(year, computer_science, c='blue')

#drugi axes
plt.axes([0.525, 0.05, 0.425, 0.9])
plt.plot(year, physical_sciences, c='green')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Subplots**

# %%
#bolj enostavno kot axes
plt.figure(figsize=(8,6), dpi=80)
plt.subplot(2,1,1)
plt.plot(year, computer_science, c='blue')
plt.title('Computer sceince')

plt.subplot(2,1,2)
plt.plot(year, physical_sciences, c='green')
plt.title('Physical science')

plt.tight_layout()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.subplot(2,2,1)
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')


plt.subplot(2,2,2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')


plt.subplot(2,2,3)
plt.plot(year, health, color='green')
plt.title('Health Professions')


plt.subplot(2,2,4)
plt.plot(year, education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Customizing axes**

# %%
#zdaj govorimo o oseh!

plt.figure(figsize=(8,6), dpi=80)


plt.plot(year,computer_science, color='red') 
plt.plot(year, physical_sciences, color='blue')

plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

plt.xlim(1990, 2010)
plt.ylim(0, 50)

plt.title('Degrees awarded to women (1990-2010)\nComputer Science (red)\nPhysical Sciences (blue)')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %%
plt.figure(figsize=(8,6), dpi=80)

plt.plot(year,computer_science, color='blue')
plt.plot(year, physical_sciences,color='red')

#isto kot xlim, ylim
plt.axis((1990, 2010, 0, 50))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Using legend()**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')

plt.legend(loc='lower center')

plt.xlabel('Year')
plt.ylabel('Degrees awarded to women (%)')

plt.title('Undergraduate enrollment of women')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Using annotate()**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')
plt.legend(loc='lower right')


cs_max = computer_science.max()
yr_max = year[computer_science.argmax()]

plt.annotate('Maksimum', xy=(yr_max, cs_max), xytext=(yr_max+5, cs_max+5),
            arrowprops=dict(facecolor='black'))


plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Modifying styles**

# %%
print(plt.style.available)
# Out:
# ['seaborn-colorblind', 'seaborn-paper', 'seaborn-dark', 'dark_background', 'seaborn-darkgrid', 'classic', 'grayscale', 'ggplot', 'seaborn-talk', 'bmh', 'seaborn-dark-palette', 'seaborn', 'seaborn-bright', 'fivethirtyeight', 'seaborn-poster', 'tableau-colorblind10', 'Solarize_Light2', 'seaborn-white', 'fast', '_classic_test', 'seaborn-notebook', 'seaborn-muted', 'seaborn-ticks', 'seaborn-deep', 'seaborn-whitegrid', 'seaborn-pastel']

# %%
plt.figure(figsize=(8,6), dpi=80)

plt.style.use('Solarize_Light2')




plt.subplot(2, 2, 1) 
plt.plot(year, physical_sciences, color='blue')
plt.title('Physical Sciences')

plt.subplot(2, 2, 2)
plt.plot(year, computer_science, color='red')
plt.title('Computer Science')

cs_max = computer_science.max()
yr_max = year[computer_science.argmax()]
plt.annotate('Maximum', xy=(yr_max, cs_max), xytext=(yr_max-1, cs_max-10), arrowprops=dict(facecolor='black'))


plt.subplot(2, 2, 3)
plt.plot(year, health, color='green')
plt.title('Health Professions')


plt.subplot(2, 2, 4)
plt.plot(year, education, color='yellow')
plt.title('Education')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# **Ticks**

# %%
plt.figure(figsize=(8,6), dpi=80)


plt.plot(year, computer_science, color='red', label='Computer Science') 
plt.plot(year, physical_sciences, color='blue', label='Physical Sciences')


plt.legend(loc='lower center')


plt.xlabel('Year')
plt.ylabel('Enrollment (%)')
plt.title('Undergraduate enrollment of women')

plt.xticks(np.linspace(1970, 2015, 10, endpoint=True))
plt.yticks(np.linspace(0, 50, 26, endpoint=True))

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.75">

# %% [markdown]
# ### Vrste grafov

# %%
#Regular Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

plt.axes([0.025,0.025,0.95,0.95])

plt.plot (X, Y+1, color='blue', alpha=1.00)
plt.fill_between(X, 1, Y+1, color='blue', alpha=.25)

plt.plot (X, Y-1, color='blue', alpha=1.00)
plt.fill_between(X, -1, Y-1, (Y-1) > -1, color='blue', alpha=.25)
plt.fill_between(X, -1, Y-1, (Y-1) < -1, color='red',  alpha=.25)

plt.xlim(-np.pi,np.pi), plt.xticks([])
plt.ylim(-2.5,2.5), plt.yticks([])
# savefig('../figures/plot_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
#Scatter Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)
T = np.arctan2(Y,X)

plt.axes([0.025,0.025,0.95,0.95])
plt.scatter(X,Y, s=75, c=T, alpha=.5)

plt.xlim(-1.5,1.5), plt.xticks([])
plt.ylim(-1.5,1.5), plt.yticks([])
# savefig('../figures/scatter_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
#Bar Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.axes([0.025,0.025,0.95,0.95])
plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')

for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.05, '%.2f' % y, ha='center', va= 'top')

plt.xlim(-.5,n), plt.xticks([])
plt.ylim(-1.25,+1.25), plt.yticks([])

# savefig('../figures/bar_ex.png', dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
#Contour Plots
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

def f(x,y):
    return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.axes([0.025,0.025,0.95,0.95])

plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap=plt.cm.hot)
C = plt.contour(X, Y, f(X,Y), 8, colors='black')
plt.clabel(C, inline=1, fontsize=10)

plt.xticks([]), plt.yticks([])
# savefig('../figures/contour_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
#Pie Charts
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

n = 20
Z = np.ones(n)
Z[-1] *= 2

plt.axes([0.025,0.025,0.95,0.95])

plt.pie(Z, explode=Z*.05, colors = ['%f' % (i/float(n)) for i in range(n)])
plt.gca().set_aspect('equal')
plt.xticks([]), plt.yticks([])

# savefig('../figures/pie_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
#Polar Axis
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(6,3), dpi=80)

ax = plt.axes([0.025,0.025,0.95,0.95], polar=True)

N = 20
theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor( plt.cm.jet(r/10.))
    bar.set_alpha(0.5)

ax.set_xticklabels([])
ax.set_yticklabels([])
# savefig('../figures/polar_ex.png',dpi=48)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# ### Ploting two-dimensional arrays

# %% [markdown]
# **Generating meshes**

# %%
import numpy as np
Y,X = np.meshgrid(range(10),range(20))

# %%
plt.figure(figsize=(6,4), dpi=80)


u = np.linspace(-2, 2, 41)
v = np.linspace(-1, 1, 21)

X, Y = np.meshgrid(u,v)
Z = np.sin(3*np.sqrt(X**2 + Y**2))
plt.pcolor(Z)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# **Contour & filled contour plots**

# %%
plt.figure(figsize=(6,4), dpi=80)

plt.subplot(2,2,1)
plt.contourf(X,Y,Z,20, cmap='viridis')
plt.colorbar()
plt.title('Viridis')


plt.subplot(2,2,2)
plt.contourf(X,Y,Z,20, cmap='gray')
plt.colorbar()
plt.title('Gray')


plt.subplot(2,2,3)
plt.contourf(X,Y,Z,20, cmap='autumn')
plt.colorbar()
plt.title('Autumn')


plt.subplot(2,2,4)
plt.contourf(X,Y,Z,20, cmap='winter')
plt.colorbar()
plt.title('Winter')


plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# ### Analiza časovnih vrst

# %% [markdown]
# ***Multiple time series on common axes***

# %%
import pandas as pd

# %%
stocks = pd.read_csv('data/DATA_stocks.csv')
stocks.head()
# Out:
#          Date        AAPL       IBM      CSCO      MSFT
# 0  2000-01-03  111.937502  116.0000  108.0625  116.5625
# 1  2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2  2000-01-05  103.999997  116.0000  101.6875  113.8125
# 3  2000-01-06   94.999998  114.0000  100.0000  110.0000
# 4  2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 5 columns):
# Date    3521 non-null object
# AAPL    3521 non-null float64
# IBM     3521 non-null float64
# CSCO    3521 non-null float64
# MSFT    3521 non-null float64
# dtypes: float64(4), object(1)
# memory usage: 137.6+ KB

# %%
#stolpec z datumi spremenimi iz object v datetime
stocks['Date'] = pd.to_datetime(stocks['Date'])

# %%
stocks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3521 entries, 0 to 3520
# Data columns (total 5 columns):
# Date    3521 non-null datetime64[ns]
# AAPL    3521 non-null float64
# IBM     3521 non-null float64
# CSCO    3521 non-null float64
# MSFT    3521 non-null float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 137.6 KB

# %%
#datum nastavimo za indeks
stocks = stocks.set_index('Date')
stocks.head()
# Out:
#                   AAPL       IBM      CSCO      MSFT
# Date
# 2000-01-03  111.937502  116.0000  108.0625  116.5625
# 2000-01-04  102.500003  112.0625  102.0000  112.6250
# 2000-01-05  103.999997  116.0000  101.6875  113.8125
# 2000-01-06   94.999998  114.0000  100.0000  110.0000
# 2000-01-07   99.500001  113.5000  105.8750  111.4375

# %%
aapl = stocks['AAPL']
ibm = stocks['IBM']
csco = stocks['CSCO']
msft = stocks['MSFT']

# %%
plt.figure(figsize=(6,4), dpi=80)

#appl
plt.plot(aapl, color='blue', label='AAPL')
plt.plot(ibm, color='green', label='IBM')
plt.plot(csco, color='red', label='CSCO')
plt.plot(msft, color='magenta', label='MSFT')


plt.legend(loc='upper left')
plt.xticks(rotation=60)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">
# /home/luka/anaconda3/lib/python3.7/site-packages/pandas/plotting/_converter.py:129: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# **Multiple time series slices**

# %%
plt.figure(figsize=(6,4), dpi=80)


plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('AAPL: All time')
plt.plot(aapl, color='blue')

#to zna narediti zaradi indeksa
view = aapl['2007':'2008']

plt.subplot(2,1,2)
plt.xticks(rotation=45)
plt.title('AAPL: 2007-2008')
plt.plot(view, color='black')

plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %%
plt.figure(figsize=(6,4), dpi=80)

#ni treba napisati prav celega datuma
view = aapl['2007-11':'2008-04']


plt.subplot(2,1,1)
plt.plot(view, color='red')
plt.title('AAPL: Nov. 2007 to Apr. 2008')
plt.xticks(rotation=45)


view = aapl['2008-01']


plt.subplot(2,1,2)
plt.plot(view, color='green')
plt.title('AAPL: Jan. 2008')
plt.xticks(rotation=45)


plt.tight_layout()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# **Plotting an inset view**

# %%
plt.figure(figsize=(6,4), dpi=80)

view = aapl['2007-11':'2008-04']


plt.plot(aapl)
plt.xticks(rotation=45)
plt.title('AAPL: 2001-2011')

#drugi graf
plt.axes([0.25,0.5, 0.35, 0.30])


plt.plot(view, color='blue')
plt.xticks(rotation=45)
plt.title('2007/11-2008/04')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="480">

# %% [markdown]
# ### Pandas df.plot

# %% [markdown]
# #### Data preparation
#
# [OECD](https://data.oecd.org/unemp/unemployment-rate.htm)

# %%
oecd = pd.read_csv('data/DATA_oecd.csv')
oecd.info()
oecd.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 8 columns):
# LOCATION      119 non-null object
# INDICATOR     119 non-null object
# SUBJECT       119 non-null object
# MEASURE       119 non-null object
# FREQUENCY     119 non-null object
# TIME          119 non-null int64
# Value         119 non-null float64
# Flag Codes    8 non-null object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 7.5+ KB
#   LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME     Value Flag Codes
# 0      AUS     UNEMP     TOT   PC_LF         A  1986  8.081038        NaN
# 1      AUS     UNEMP     TOT   PC_LF         A  1987  8.108040        NaN
# 2      AUS     UNEMP     TOT   PC_LF         A  1988  7.227954        NaN
# 3      AUS     UNEMP     TOT   PC_LF         A  1989  6.179825        NaN
# 4      AUS     UNEMP     TOT   PC_LF         A  1990  6.923000        NaN

# %%
columns_to_drop = ['INDICATOR', 'SUBJECT','FREQUENCY','MEASURE', 'Flag Codes']
oecd.drop(columns=columns_to_drop, inplace=True)

# %%
#podatki so tako, da so v stolpcu LOCATION države ena pod drugo
#na koncu pa bomo želeli narisati za vsako državo posebej
oecd.head()
# Out:
#   LOCATION  TIME     Value
# 0      AUS  1986  8.081038
# 1      AUS  1987  8.108040
# 2      AUS  1988  7.227954
# 3      AUS  1989  6.179825
# 4      AUS  1990  6.923000

# %% [markdown]
# #### pandas vs matplotlib

# %% [markdown]
# #### Which .plot do I use?

# %% [markdown]
# #### Plotting Version 1: .plot plots the index against every column

# %%
oecd[35:40]
# Out:
#    LOCATION  TIME     Value
# 35      AUT  1988  3.563734
# 36      AUT  1989  3.132628
# 37      AUT  1990  3.240462
# 38      AUT  1991  3.475676
# 39      AUT  1992  3.593146

# %%
#če ne nastavimo nič, vzame indeks kot x os in ostalo kar lahko nariše na y os
oecd.plot()
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %%
mean_val = oecd.groupby('LOCATION')['Value'].mean()
mean_val
# Out:
# LOCATION
# AUS    6.725630
# AUT    4.396571
# BEL    7.727318
# CAN    7.954041
# Name: Value, dtype: float64

# %%
plt.figure()
mean_val.plot(kind='bar')
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %% [markdown]
# #### Plotting Version 2: .plot(x='col1') plots against a single specific column
#
# Več o tem v naslednjem poglaviju.
#
# #### Plotting Version 3: .plot(x='col1', y='col2') plots one specific column against another specific column

# %%
oecd.plot(x='TIME', y='Value')
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %%
#dobimo 4 grafe, želimo pa vse na enem
oecd.groupby('LOCATION').plot(x='TIME', y='Value')
# Out:
# <img src="data:image/png;base64,..." width="852.75">
# <img src="data:image/png;base64,..." width="852.75">
# <img src="data:image/png;base64,..." width="852.75">
# <img src="data:image/png;base64,..." width="852.75">
# LOCATION
# AUS    AxesSubplot(0.125,0.11;0.775x0.77)
# AUT    AxesSubplot(0.125,0.11;0.775x0.77)
# BEL    AxesSubplot(0.125,0.11;0.775x0.77)
# CAN    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %%
fig, ax = plt.subplots()
oecd.groupby('LOCATION').plot(x='TIME', y='Value', ax=ax, legend=False)
# Out:
# <img src="data:image/png;base64,..." width="852.75">
# LOCATION
# AUS    AxesSubplot(0.125,0.11;0.775x0.77)
# AUT    AxesSubplot(0.125,0.11;0.775x0.77)
# BEL    AxesSubplot(0.125,0.11;0.775x0.77)
# CAN    AxesSubplot(0.125,0.11;0.775x0.77)
# dtype: object

# %% [markdown]
# #### Primeri

# %% [markdown]
# ##### Basic Plotting: plot

# %%
df = pd.DataFrame(np.random.randn(10,4),
                  index=pd.date_range('1/1/2000',periods=10), 
                  columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2000-01-01  0.625441  0.372228 -0.958097  0.232971
# 2000-01-02  1.347376 -0.101701 -0.304210  0.852400
# 2000-01-03 -0.589056  0.782849  0.438872 -0.086774
# 2000-01-04 -0.676911  0.231549  0.520162  2.227553
# 2000-01-05 -1.181573  0.456206 -1.405633 -0.078866
# 2000-01-06  0.985149  0.645826  1.008015 -1.539852
# 2000-01-07 -0.107659 -1.346287  0.002546 -0.266235
# 2000-01-08 -0.930976 -0.697279  0.855530 -0.177033
# 2000-01-09  0.399862 -0.047534 -0.453873  0.409783
# 2000-01-10 -1.345487 -0.954444  0.989611 -1.101903

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %% [markdown]
# ##### Bar Plot

# %%
df = pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.plot(kind='bar', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="852.75">

# %% [markdown]
# ### seaborn: statistical data visualization
#
# > [Seaborn dokumentacija](https://seaborn.pydata.org/)

# %% [markdown]
# **Simple linear regressions**

# %%
#uvoz podatkov
import pandas as pd

auto = pd.read_csv('data/DATA_auto-mpg.csv')

# %%
#visokonivojski program za risanje, veliko različnih že pripravljenih grafov
import seaborn as sns

# %%
auto.head()
# Out:
#     mpg  cyl  displ   hp  weight  accel  yr  origin              name  color  \
# 0  18.0    6  250.0   88    3139   14.5  71      US      ford mustang    red
# 1   9.0    8  304.0  193    4732   18.5  70      US          hi 1200d  green
# 2  36.1    4   91.0   60    1800   16.4  78    Asia  honda civic cvcc   blue
# 3  18.5    6  250.0   98    3525   19.0  77      US      ford granada    red
# 4  34.3    4   97.0   78    2188   15.8  80  Europe         audi 4000   blue
#
#         size marker
# 0  27.370336      o
# 1  62.199511      o
# 2   9.000000      x
# 3  34.515625      o
# 4  13.298178      s

# %%
sns.lmplot(data=auto, x='weight', y='hp')
# Out:
# <img src="data:image/png;base64,..." width="499.5">
